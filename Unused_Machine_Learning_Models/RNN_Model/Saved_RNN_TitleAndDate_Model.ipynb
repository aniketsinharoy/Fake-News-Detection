# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
from wordcloud import WordCloud #for text data visualixation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# TensorFlow is a Python library for fast numerical computing created and released by Google. It is a foundation library that can be used to create Deep Learning models directly or by using wrapper libraries that simplify the process built on top of TensorFlow.
#   In Deep Learning, Recurrent Neural Networks (RNN) are a family of neural networks that excels in learning from sequential data. A class of RNN that has found practical applications is Long Short-Term Memory (LSTM) because it is robust against the problems of long-term dependency.
#   LSTM is mostly used in scenarios where we have no idea of the time duration and we need to process, classify and predict the series of time it will take. The use of the LSTM is mostly used for remembering the post data inside the system memory that is also considered as the updated or modified version of RNN that is a Recurrent neural network that makes the work of remembering easy.

# %%
from tensorflow.keras.preprocessing.text import Tokenizer #used to tokenize the text data
from tensorflow.keras.preprocessing.sequence import pad_sequences #used to pad those datasets which are not long enough
from tensorflow.keras.models import Sequential #for feeding the model layers
from tensorflow.keras.layers import Dense, Embedding, LSTM, Conv1D, MaxPool1D
from sklearn.model_selection import train_test_split #used to split dataset into train set and test set
from sklearn.metrics import classification_report, accuracy_score #used to measure the performance

# %%
fake= pd.read_csv('https://raw.githubusercontent.com/laxmimerit/fake-real-news-dataset/main/data/Fake.csv')

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
fake.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
fake['subject'].value_counts() #how many subjects of data are there
# Out:
# News               9050
# politics           6841
# left-news          4459
# Government News    1570
# US_News             783
# Middle-east         778
# Name: subject, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot('subject',data=fake)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
text =' '.join(fake['text'].tolist())

# %%
wordcloud= WordCloud(width=1920, height=1080).generate(text)
fig = plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
real= pd.read_csv('https://raw.githubusercontent.com/laxmimerit/fake-real-news-dataset/main/data/True.csv')

# %%
text =' '.join(real['text'].tolist())

# %%
wordcloud= WordCloud(width=1920, height=1080).generate(text)
fig = plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# **CLEANING DATA**

# %%
real.sample(15)
# Out:
#                                                    title  \
# 9555   Trump says Amazon.com has 'a huge antitrust pr...
# 13615  Singapore charges activist for organizing asse...
# 14539  Exclusive: North Korea rules out negotiations ...
# 11997  Nigerian oil union PENGASSAN suspends strike: ...
# 7498   Factbox: State-by-state poll closing times for...
# 19412  U.S. announces near $700 million in humanitari...
# 1076   Factbox: Trump on Twitter (Oct 24) - Bob Corke...
# 12835  Army chief says Pakistan should 'revisit' Isla...
# 11843  Beijing condemns Taiwan probe into tiny pro-Ch...
# 17491  South Africa's ANC needs to put an end to scan...
# 8798   Obama renews call for U.S. public health insur...
# 1229   Republican Senator Collins likely 'yes' vote t...
# 6520        Exxon Mobil, Tillerson agree to cut all ties
# 818    House Speaker Ryan says special counsel should...
# 5075   Los Angeles mayor appears headed for re-electi...
#
#                                                     text       subject  \
# 9555   WASHINGTON (Reuters) - U.S. Republican preside...  politicsNews
# 13615  SINGAPORE (Reuters) - Singapore authorities ch...     worldnews
# 14539  GENEVA (Reuters) - North Korea on Friday ruled...     worldnews
# 11997  ABUJA (Reuters) - A major Nigerian oil union s...     worldnews
# 7498   (Reuters) - The following table lists each sta...  politicsNews
# 19412  UNITED NATIONS (Reuters) - The U.S. State Depa...     worldnews
# 1076   The following statements were posted to the ve...  politicsNews
# 12835  QUETTA, Pakistan (Reuters) - Pakistan s army c...     worldnews
# 11843  BEIJING/TAIPEI (Reuters) - China has condemned...     worldnews
# 17491  JOHANNESBURG (Reuters) - South Africa s ruling...     worldnews
# 8798   (Reuters) - President Barack Obama on Monday u...  politicsNews
# 1229   WASHINGTON (Reuters) - U.S. Republican Senator...  politicsNews
# 6520   (Reuters) - Exxon Mobil Corp and Rex Tillerson...  politicsNews
# 818    WASHINGTON (Reuters) - U.S. House Speaker Paul...  politicsNews
# 5075   LOS ANGELES (Reuters) - Los Angeles Mayor Eric...  politicsNews
#
#                       date
# 9555         May 13, 2016
# 13615   November 29, 2017
# 14539   November 17, 2017
# 11997   December 18, 2017
# 7498     November 8, 2016
# 19412  September 21, 2017
# 1076     October 24, 2017
# 12835    December 7, 2017
# 11843   December 20, 2017
# 17491    October 14, 2017
# 8798        July 11, 2016
# 1229     October 15, 2017
# 6520      January 4, 2017
# 818      November 5, 2017
# 5075        March 7, 2017

# %%
unknown_publishers = []
for index, row in enumerate(real.text.values):
  try:
    record=row.split('-', maxsplit=1)
    record[1]
    assert(len(record[0])<120)
  except:
    unknown_publishers.append(index)

# %%
len(unknown_publishers)
# Out:
# 222

# %%
real.iloc[unknown_publishers]
# Out:
#                                                    title  \
# 7      Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8             Trump on Twitter (Dec 28) - Global Warming
# 12     Factbox: Trump on Twitter (Dec 28) - Vanity Fa...
# 13        Trump on Twitter (Dec 27) - Trump, Iraq, Syria
# 14     Man says he delivered manure to Mnuchin to pro...
# ...                                                  ...
# 20135  China's big money trumps U.S. influence in Cam...
# 20500  UK publisher rejected request to block academi...
# 20667  Rohingya say their village is lost to Myanmar'...
# 21246  'Gates of Hell': Iraqi army says fighting near...
# 21339  Indian court's privacy ruling is blow to gover...
#
#                                                     text       subject  \
# 7      The following statements were posted to the ve...  politicsNews
# 8      The following statements were posted to the ve...  politicsNews
# 12     The following statements were posted to the ve...  politicsNews
# 13     The following statements were posted to the ve...  politicsNews
# 14      (In Dec. 25 story, in second paragraph, corre...  politicsNews
# ...                                                  ...           ...
# 20135   (Story corrects to million from billion in pa...     worldnews
# 20500   (This Sept 8 story corrects headline, clarifi...     worldnews
# 20667   (Story refiles to add dropped word  not , in ...     worldnews
# 21246   (Story corrects third paragraph to show Mosul...     worldnews
# 21339   (Story corrects to fix spelling in paragraph ...     worldnews
#
#                       date
# 7       December 29, 2017
# 8       December 29, 2017
# 12      December 28, 2017
# 13      December 28, 2017
# 14      December 25, 2017
# ...                    ...
# 20135  September 11, 2017
# 20500   September 8, 2017
# 20667   September 7, 2017
# 21246     August 29, 2017
# 21339     August 24, 2017
#
# [222 rows x 4 columns]

# %%
real.iloc[8970]
# Out:
# title      Graphic: Supreme Court roundup
# text
# subject                      politicsNews
# date                       June 16, 2016
# Name: 8970, dtype: object

# %%
real = real.drop(8970, axis=0)

# %%
publisher=[]
tmp_text=[]

for index, row in enumerate(real.text.values):
  if index in unknown_publishers:
    tmp_text.append(row)
    publisher.append('Unknown')
  else:
    record = row.split('-', maxsplit=1)
    publisher.append(record[0].strip())
    tmp_text.append(record[1].strip())

# %%
real['publisher']=publisher
real['text']=tmp_text

# %%
real.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  The head of a conservative Republican faction ...  politicsNews
# 1  Transgender people will be allowed for the fir...  politicsNews
# 2  The special counsel investigation of links bet...  politicsNews
# 3  Trump campaign adviser George Papadopoulos tol...  politicsNews
# 4  President Donald Trump called on the U.S. Post...  politicsNews
#
#                  date                     publisher
# 0  December 31, 2017           WASHINGTON (Reuters)
# 1  December 29, 2017           WASHINGTON (Reuters)
# 2  December 31, 2017           WASHINGTON (Reuters)
# 3  December 30, 2017           WASHINGTON (Reuters)
# 4  December 29, 2017   SEATTLE/WASHINGTON (Reuters)

# %%
real.shape
# Out:
# (21416, 5)

# %%
empty_fake_index=[index for index,text in enumerate(fake.text.tolist()) if str(text).strip()==""]

# %%
fake.iloc[empty_fake_index]
# Out:
#                                                    title text    subject  \
# 10923  TAKE OUR POLL: Who Do You Think President Trum...        politics
# 11041  Joe Scarborough BERATES Mika Brzezinski Over “...        politics
# 11190  WATCH TUCKER CARLSON Scorch Sanctuary City May...        politics
# 11225  MAYOR OF SANCTUARY CITY: Trump Trying To Make ...        politics
# 11236  SHOCKER: Public School Turns Computer Lab Into...        politics
# ...                                                  ...  ...        ...
# 21816  BALTIMORE BURNS: MARYLAND GOVERNOR BRINGS IN N...       left-news
# 21826  FULL VIDEO: THE BLOCKBUSTER INVESTIGATION INTO...       left-news
# 21827  (VIDEO) HILLARY CLINTON: RELIGIOUS BELIEFS MUS...       left-news
# 21857  (VIDEO)ICE PROTECTING OBAMA: WON’T RELEASE NAM...       left-news
# 21873  (VIDEO) HYSTERICAL SNL TAKE ON HILLARY’S ANNOU...       left-news
#
#                date
# 10923  May 10, 2017
# 11041  Apr 26, 2017
# 11190   Apr 6, 2017
# 11225   Apr 2, 2017
# 11236   Apr 1, 2017
# ...             ...
# 21816  Apr 27, 2015
# 21826  Apr 25, 2015
# 21827  Apr 25, 2015
# 21857  Apr 14, 2015
# 21873  Apr 12, 2015
#
# [630 rows x 4 columns]

# %%
real['text']=real['title'] + real['date']
fake['text']=fake['title'] + fake['date']

# %%
real['text']=real['text'].apply(lambda x: str(x).lower())
fake['text']=fake['text'].apply(lambda x: str(x).lower())

# %% [markdown]
# **Preprocessing Data**

# %%
real['class']=1
fake['class']=0

# %%
real.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'publisher', 'class'], dtype='object')

# %%
real=real[['text','class']]
fake=fake[['text','class']]

# %%
data=real.append(fake, ignore_index=True)

# %%
data.sample(5)
# Out:
#                                                     text  class
# 24954   carrier makes appalling announcement less tha...      0
# 11990  south sudan rebels accuse army of attack as pe...      1
# 3451   three lawmakers question kushner cos on concer...      1
# 577    white house wants republican in alabama senate...      1
# 11040  virginia lawmakers reach bipartisan deal on gu...      1

# %%
# !pip install spacy==2.2.3
# !python -m spacy download en_core_web_sm
# !pip install beautifulsoup4==4.9.1
# !pip install textblob==0.15.3
# !pip install git+https://github.com/laxmimerit/preprocess_kgptalkie.git --upgrade --force-reinstall
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spacy==2.2.3
#   Downloading spacy-2.2.3-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 68.2 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy==2.2.3) (2.25.1)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy==2.2.3) (1.21.6)
# Collecting blis<0.5.0,>=0.4.0
#   Downloading blis-0.4.1-cp38-cp38-manylinux1_x86_64.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 70.7 MB/s eta 0:00:00
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy==2.2.3) (1.0.9)
# Collecting thinc<7.4.0,>=7.3.0
#   Downloading thinc-7.3.1-cp38-cp38-manylinux1_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 59.9 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy==2.2.3) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy==2.2.3) (2.0.7)
# Collecting srsly<1.1.0,>=0.1.0
#   Downloading srsly-1.0.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 KB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy==2.2.3) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy==2.2.3) (3.0.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (2.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.8/dist-packages (from thinc<7.4.0,>=7.3.0->spacy==2.2.3) (4.64.1)
# Installing collected packages: plac, srsly, catalogue, blis, thinc, spacy
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.5
#     Uninstalling srsly-2.4.5:
#       Successfully uninstalled srsly-2.4.5
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.8
#     Uninstalling catalogue-2.0.8:
#       Successfully uninstalled catalogue-2.0.8
#   Attempting uninstall: blis
#     Found existing installation: blis 0.7.9
#     Uninstalling blis-0.7.9:
#       Successfully uninstalled blis-0.7.9
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.7
#     Uninstalling thinc-8.1.7:
#       Successfully uninstalled thinc-8.1.7
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.4
#     Uninstalling spacy-3.4.4:
#       Successfully uninstalled spacy-3.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 3.4.1 requires spacy<3.5.0,>=3.4.0, but you have spacy 2.2.3 which is incompatible.
# confection 0.0.4 requires srsly<3.0.0,>=2.4.0, but you have srsly 1.0.6 which is incompatible.
# Successfully installed blis-0.4.1 catalogue-1.0.2 plac-1.1.3 spacy-2.2.3 srsly-1.0.6 thinc-7.3.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 15.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.8/dist-packages (from en_core_web_sm==2.2.5) (2.2.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.7)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.10.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.3.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.21.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.25.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.9)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.0.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.8/dist-packages (from thinc<7.4.0,>=7.3.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.64.1)
# Building wheels for collected packages: en_core_web_sm
#   Building wheel for en_core_web_sm (setup.py) ... done
#   Created wheel for en_core_web_sm: filename=en_core_web_sm-2.2.5-py3-none-any.whl size=12011738 sha256=70c775a223a368e2dd0cd434390181103b89bf33aa82c3dd5750a781f7ca4f63
#   Stored in directory: /tmp/pip-ephem-wheel-cache-h9vounbv/wheels/77/b4/c8/395804b9a2b6864aaff3623d7b709680acc3d04f47c8162ee6
# Successfully built en_core_web_sm
# Installing collected packages: en_core_web_sm
#   Attempting uninstall: en_core_web_sm
#     Found existing installation: en-core-web-sm 3.4.1
#     Uninstalling en-core-web-sm-3.4.1:
#       Successfully uninstalled en-core-web-sm-3.4.1
# Successfully installed en_core_web_sm-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting beautifulsoup4==4.9.1
#   Downloading beautifulsoup4-4.9.1-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 KB 10.8 MB/s eta 0:00:00
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, beautifulsoup4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.9.1 soupsieve-2.3.2.post1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: textblob==0.15.3 in /usr/local/lib/python3.8/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.8/dist-packages (from textblob==0.15.3) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob==0.15.3) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob==0.15.3) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob==0.15.3) (4.64.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob==0.15.3) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/laxmimerit/preprocess_kgptalkie.git
#   Cloning https://github.com/laxmimerit/preprocess_kgptalkie.git to /tmp/pip-req-build-xszgabx4
#   Running command git clone --filter=blob:none --quiet https://github.com/laxmimerit/preprocess_kgptalkie.git /tmp/pip-req-build-xszgabx4
#   Resolved https://github.com/laxmimerit/preprocess_kgptalkie.git to commit 9ca68d37027af9f6a30d54640347ce3b2e2694b3
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: preprocess-kgptalkie
#   Building wheel for preprocess-kgptalkie (setup.py) ... done
#   Created wheel for preprocess-kgptalkie: filename=preprocess_kgptalkie-0.1.3-py3-none-any.whl size=7650 sha256=847ceb927634a7787019ca006190945c9f174883e5f9319d757ab144aba74243
#   Stored in directory: /tmp/pip-ephem-wheel-cache-srw_ata_/wheels/fd/71/47/e04f208ad659a295ccb69022e14de7d20ccc6fc30a5a935f09
# Successfully built preprocess-kgptalkie
# Installing collected packages: preprocess-kgptalkie
# Successfully installed preprocess-kgptalkie-0.1.3

# %%
import preprocess_kgptalkie as ps

# %%
data['text']=data['text'].apply(lambda x: ps.remove_special_chars(x))

# %%
data.head()
# Out:
#                                                 text  class
# 0  as us budget fight looms republicans flip thei...      1
# 1  us military to accept transgender recruits on ...      1
# 2  senior us republican senator let mr mueller do...      1
# 3  fbi russia probe helped by australian diplomat...      1
# 4  trump wants postal service to charge much more...      1

# %% [markdown]
# **Vectorization**

# %%
import gensim

# %%
y=data['class'].values

# %%
X=[d.split() for d in data['text'].tolist()]

# %%
print(X[0])
# Out:
# ['as', 'us', 'budget', 'fight', 'looms', 'republicans', 'flip', 'their', 'fiscal', 'scriptdecember', '31', '2017']

# %%
DIM = 100
w2v_model= gensim.models.Word2Vec(sentences= X, size= DIM, window= 10, min_count=1)

# %%
len(w2v_model.wv.vocab)
# Out:
# 42957

# %%
w2v_model.wv.most_similar('trump')
# Out:
# [('trumps', 0.9503913521766663),
#  ('obama', 0.8779554963111877),
#  ('grateful', 0.8570224046707153),
#  ('unaware', 0.8523872494697571),
#  ('wonhillary', 0.848325252532959),
#  ('she', 0.8418740034103394),
#  ('farleft', 0.8342361450195312),
#  ('kiss', 0.833014965057373),
#  ('he', 0.8290176391601562),
#  ('it', 0.828691303730011)]

# %%
tokenizer= Tokenizer()
tokenizer.fit_on_texts(X)#The fit_on_texts method is a part of Keras tokenizer class which is used to update the internal vocabulary for the texts list. We need to call be before using other methods of texts_to_sequences or texts_to_matrix.

# %%
X = tokenizer.texts_to_sequences(X)

# %%
tokenizer.word_index
# Out:
# {'2017': 1,
#  'to': 2,
#  '2016': 3,
#  'trump': 4,
#  'in': 5,
#  'of': 6,
#  'for': 7,
#  'on': 8,
#  'the': 9,
#  'us': 10,
#  'a': 11,
#  'and': 12,
#  'with': 13,
#  'says': 14,
#  'is': 15,
#  'after': 16,
#  '2015': 17,
#  'obama': 18,
#  'at': 19,
#  'trumps': 20,
#  'as': 21,
#  'from': 22,
#  'by': 23,
#  'over': 24,
#  'about': 25,
#  'watch': 26,
#  'his': 27,
#  'not': 28,
#  'new': 29,
#  '13': 30,
#  'hillary': 31,
#  '6': 32,
#  '7': 33,
#  '20': 34,
#  'white': 35,
#  '9': 36,
#  'will': 37,
#  'house': 38,
#  '8': 39,
#  '10': 40,
#  '15': 41,
#  '12': 42,
#  '14': 43,
#  '1': 44,
#  '4': 45,
#  '5': 46,
#  '27': 47,
#  '21': 48,
#  '16': 49,
#  '22': 50,
#  '18': 51,
#  '17': 52,
#  '19': 53,
#  '11': 54,
#  '26': 55,
#  '3': 56,
#  '2': 57,
#  'clinton': 58,
#  '23': 59,
#  '28': 60,
#  'just': 61,
#  'be': 62,
#  '24': 63,
#  '25': 64,
#  'he': 65,
#  'president': 66,
#  '29': 67,
#  '30': 68,
#  'this': 69,
#  'out': 70,
#  'who': 71,
#  'it': 72,
#  'that': 73,
#  'are': 74,
#  'republican': 75,
#  'video': 76,
#  'up': 77,
#  'north': 78,
#  'against': 79,
#  'russia': 80,
#  'bill': 81,
#  'you': 82,
#  'was': 83,
#  'has': 84,
#  'state': 85,
#  'her': 86,
#  'donald': 87,
#  'breaking': 88,
#  'court': 89,
#  'black': 90,
#  'news': 91,
#  'how': 92,
#  'senate': 93,
#  'calls': 94,
#  'no': 95,
#  'why': 96,
#  '31': 97,
#  'him': 98,
#  'have': 99,
#  'republicans': 100,
#  'more': 101,
#  'tax': 102,
#  'gop': 103,
#  'obamas': 104,
#  'korea': 105,
#  'its': 106,
#  'videomay': 107,
#  'police': 108,
#  'media': 109,
#  'what': 110,
#  'if': 111,
#  'down': 112,
#  'muslim': 113,
#  'election': 114,
#  'may': 115,
#  'vote': 116,
#  'one': 117,
#  'campaign': 118,
#  'gets': 119,
#  'china': 120,
#  'russian': 121,
#  'democrats': 122,
#  'into': 123,
#  'iran': 124,
#  'former': 125,
#  'they': 126,
#  'back': 127,
#  'un': 128,
#  'fbi': 129,
#  'first': 130,
#  'their': 131,
#  'top': 132,
#  'during': 133,
#  'people': 134,
#  'party': 135,
#  'tells': 136,
#  'off': 137,
#  'senator': 138,
#  'deal': 139,
#  'government': 140,
#  'but': 141,
#  'when': 142,
#  'we': 143,
#  'attack': 144,
#  'eu': 145,
#  'all': 146,
#  'america': 147,
#  'make': 148,
#  'democrat': 149,
#  'would': 150,
#  'fox': 151,
#  'war': 152,
#  'twitter': 153,
#  'pm': 154,
#  'an': 155,
#  'security': 156,
#  'leader': 157,
#  'videonov': 158,
#  'videooct': 159,
#  'get': 160,
#  'should': 161,
#  'south': 162,
#  'man': 163,
#  'could': 164,
#  'i': 165,
#  'cnn': 166,
#  'she': 167,
#  'chief': 168,
#  'judge': 169,
#  'racist': 170,
#  'videoapr': 171,
#  'videomar': 172,
#  'plan': 173,
#  'sanders': 174,
#  'videojul': 175,
#  'talks': 176,
#  'liberal': 177,
#  'can': 178,
#  'being': 179,
#  'makes': 180,
#  'factbox': 181,
#  'wont': 182,
#  'million': 183,
#  'hillarys': 184,
#  'congress': 185,
#  'fake': 186,
#  'foreign': 187,
#  'before': 188,
#  'speech': 189,
#  'nuclear': 190,
#  'wants': 191,
#  'videojun': 192,
#  'supreme': 193,
#  'shows': 194,
#  'videoaug': 195,
#  'videodec': 196,
#  'two': 197,
#  'military': 198,
#  'presidential': 199,
#  'than': 200,
#  'like': 201,
#  'brexit': 202,
#  'gun': 203,
#  'goes': 204,
#  'say': 205,
#  'cruz': 206,
#  'your': 207,
#  'governor': 208,
#  'hes': 209,
#  'american': 210,
#  'wow': 211,
#  'under': 212,
#  'take': 213,
#  'our': 214,
#  'supporters': 215,
#  'syria': 216,
#  'videosep': 217,
#  'americans': 218,
#  'woman': 219,
#  'law': 220,
#  'illegal': 221,
#  'ban': 222,
#  'bernie': 223,
#  'support': 224,
#  'host': 225,
#  'want': 226,
#  'videomarch': 227,
#  'videojanuary': 228,
#  'most': 229,
#  'border': 230,
#  'videofebruary': 231,
#  'go': 232,
#  'putin': 233,
#  'so': 234,
#  'videojan': 235,
#  'national': 236,
#  'islamic': 237,
#  'did': 238,
#  'political': 239,
#  'dont': 240,
#  'them': 241,
#  'saudi': 242,
#  'time': 243,
#  'minister': 244,
#  'healthcare': 245,
#  'or': 246,
#  'show': 247,
#  'obamacare': 248,
#  'videofeb': 249,
#  'gives': 250,
#  'meet': 251,
#  'women': 252,
#  'report': 253,
#  'big': 254,
#  'stop': 255,
#  'only': 256,
#  'sanctions': 257,
#  'syrian': 258,
#  'ryan': 259,
#  'rights': 260,
#  'help': 261,
#  'must': 262,
#  'day': 263,
#  'german': 264,
#  'killed': 265,
#  'fight': 266,
#  'probe': 267,
#  'do': 268,
#  'climate': 269,
#  'because': 270,
#  'meeting': 271,
#  'call': 272,
#  'uk': 273,
#  'antitrump': 274,
#  'while': 275,
#  'rally': 276,
#  'warns': 277,
#  'urges': 278,
#  'conservative': 279,
#  'lawmakers': 280,
#  'old': 281,
#  'next': 282,
#  'attacks': 283,
#  'travel': 284,
#  'takes': 285,
#  'response': 286,
#  'right': 287,
#  'videoapril': 288,
#  'trade': 289,
#  'claims': 290,
#  'were': 291,
#  'caught': 292,
#  'asks': 293,
#  'turkey': 294,
#  'ted': 295,
#  'leaders': 296,
#  'going': 297,
#  'defense': 298,
#  'democratic': 299,
#  'got': 300,
#  'group': 301,
#  'room': 302,
#  'supporter': 303,
#  'end': 304,
#  'immigration': 305,
#  'candidate': 306,
#  'win': 307,
#  'now': 308,
#  'protesters': 309,
#  'world': 310,
#  'refugees': 311,
#  'death': 312,
#  'see': 313,
#  'mexico': 314,
#  'john': 315,
#  'justice': 316,
#  'press': 317,
#  'opposition': 318,
#  'secret': 319,
#  'school': 320,
#  'comey': 321,
#  'cant': 322,
#  'budget': 323,
#  'students': 324,
#  'states': 325,
#  'heres': 326,
#  'major': 327,
#  'email': 328,
#  'panel': 329,
#  'debate': 330,
#  'some': 331,
#  'huge': 332,
#  'free': 333,
#  'air': 334,
#  'hilarious': 335,
#  'way': 336,
#  'general': 337,
#  'race': 338,
#  'open': 339,
#  'still': 340,
#  'paul': 341,
#  'reporter': 342,
#  'lives': 343,
#  'official': 344,
#  'policy': 345,
#  'kill': 346,
#  'exclusive': 347,
#  'years': 348,
#  'left': 349,
#  'federal': 350,
#  'plans': 351,
#  'texas': 352,
#  'department': 353,
#  'own': 354,
#  'arrested': 355,
#  'made': 356,
#  'mayor': 357,
#  'wall': 358,
#  'last': 359,
#  'visit': 360,
#  'face': 361,
#  'money': 362,
#  'city': 363,
#  'live': 364,
#  'secretary': 365,
#  'voters': 366,
#  'need': 367,
#  'seeks': 368,
#  'move': 369,
#  'never': 370,
#  'shocking': 371,
#  'give': 372,
#  'puerto': 373,
#  'director': 374,
#  'change': 375,
#  'really': 376,
#  'leftist': 377,
#  'college': 378,
#  'cops': 379,
#  'administration': 380,
#  'threatens': 381,
#  'does': 382,
#  'clintons': 383,
#  'attorney': 384,
#  'head': 385,
#  'dead': 386,
#  'again': 387,
#  'very': 388,
#  'voter': 389,
#  'truth': 390,
#  'ahead': 391,
#  'emails': 392,
#  'boiler': 393,
#  'tillerson': 394,
#  'social': 395,
#  'conservatives': 396,
#  'health': 397,
#  'washington': 398,
#  'said': 399,
#  'myanmar': 400,
#  'another': 401,
#  'had': 402,
#  'aid': 403,
#  'even': 404,
#  'york': 405,
#  'protest': 406,
#  'interview': 407,
#  'family': 408,
#  'iraq': 409,
#  'my': 410,
#  'work': 411,
#  'officials': 412,
#  'ties': 413,
#  'key': 414,
#  'use': 415,
#  'terror': 416,
#  'great': 417,
#  'speaker': 418,
#  'latest': 419,
#  'year': 420,
#  'pick': 421,
#  'told': 422,
#  'message': 423,
#  'korean': 424,
#  'force': 425,
#  'fire': 426,
#  'violence': 427,
#  'senators': 428,
#  'amid': 429,
#  'army': 430,
#  'sexual': 431,
#  'george': 432,
#  'boom': 433,
#  'billion': 434,
#  'keep': 435,
#  'been': 436,
#  'lol': 437,
#  'push': 438,
#  'discuss': 439,
#  'run': 440,
#  'poll': 441,
#  'release': 442,
#  'dnc': 443,
#  'doesnt': 444,
#  'jerusalem': 445,
#  'isis': 446,
#  'behind': 447,
#  'matter': 448,
#  'merkel': 449,
#  'catalan': 450,
#  'pay': 451,
#  'hate': 452,
#  'terrorist': 453,
#  'order': 454,
#  'team': 455,
#  'destroys': 456,
#  'pence': 457,
#  'lawyer': 458,
#  'florida': 459,
#  'busted': 460,
#  'refugee': 461,
#  'rico': 462,
#  'nominee': 463,
#  'asked': 464,
#  'blasts': 465,
#  'coalition': 466,
#  'reason': 467,
#  'seek': 468,
#  'legal': 469,
#  'germany': 470,
#  'flag': 471,
#  'videojune': 472,
#  'lead': 473,
#  'know': 474,
#  'cop': 475,
#  'rules': 476,
#  'voting': 477,
#  'threat': 478,
#  'britain': 479,
#  'crisis': 480,
#  'terrorists': 481,
#  'home': 482,
#  'case': 483,
#  'high': 484,
#  'british': 485,
#  'list': 486,
#  'bomb': 487,
#  'lie': 488,
#  'ep': 489,
#  'muslims': 490,
#  'cut': 491,
#  'control': 492,
#  'mccain': 493,
#  'decision': 494,
#  'story': 495,
#  'ready': 496,
#  'presidency': 497,
#  'missile': 498,
#  'tweet': 499,
#  'japan': 500,
#  'trying': 501,
#  'public': 502,
#  'real': 503,
#  'found': 504,
#  'nfl': 505,
#  'forces': 506,
#  'business': 507,
#  'used': 508,
#  'wins': 509,
#  'rohingya': 510,
#  'hell': 511,
#  'best': 512,
#  'tries': 513,
#  'good': 514,
#  'iraqi': 515,
#  'intelligence': 516,
#  'three': 517,
#  'peace': 518,
#  'near': 519,
#  'backs': 520,
#  'set': 521,
#  'slams': 522,
#  'bombshell': 523,
#  'other': 524,
#  'investigation': 525,
#  'facebook': 526,
#  'shut': 527,
#  'shooting': 528,
#  'despite': 529,
#  'funding': 530,
#  'defends': 531,
#  'any': 532,
#  'bad': 533,
#  'ad': 534,
#  'kills': 535,
#  'radical': 536,
#  'turkish': 537,
#  'called': 538,
#  'special': 539,
#  'away': 540,
#  'votes': 541,
#  'himself': 542,
#  'likely': 543,
#  'rep': 544,
#  'hollywood': 545,
#  'didnt': 546,
#  'ever': 547,
#  'sees': 548,
#  'ruling': 549,
#  'using': 550,
#  'fired': 551,
#  'chair': 552,
#  'jobs': 553,
#  'too': 554,
#  'kids': 555,
#  'full': 556,
#  'dem': 557,
#  'leave': 558,
#  'job': 559,
#  'chinas': 560,
#  'lies': 561,
#  'reform': 562,
#  'needs': 563,
#  'saying': 564,
#  'orders': 565,
#  'sessions': 566,
#  'france': 567,
#  'sean': 568,
#  'wikileaks': 569,
#  'california': 570,
#  'msnbc': 571,
#  'reveals': 572,
#  'internet': 573,
#  'calling': 574,
#  'country': 575,
#  'fraud': 576,
#  'making': 577,
#  'cia': 578,
#  'young': 579,
#  'chicago': 580,
#  'post': 581,
#  'believe': 582,
#  'every': 583,
#  'put': 584,
#  'admits': 585,
#  'possible': 586,
#  'between': 587,
#  'bush': 588,
#  'times': 589,
#  'shot': 590,
#  'bid': 591,
#  'arrest': 592,
#  'son': 593,
#  'hurricane': 594,
#  'think': 595,
#  'joe': 596,
#  'israel': 597,
#  'videoseptember': 598,
#  'executive': 599,
#  'hit': 600,
#  'working': 601,
#  'power': 602,
#  'brutal': 603,
#  'without': 604,
#  'french': 605,
#  'destroy': 606,
#  'senior': 607,
#  'congressman': 608,
#  'lying': 609,
#  'hold': 610,
#  'independence': 611,
#  'violent': 612,
#  'rape': 613,
#  'lawmaker': 614,
#  'adviser': 615,
#  'tv': 616,
#  'exposes': 617,
#  'parliament': 618,
#  'sarah': 619,
#  'final': 620,
#  'planned': 621,
#  'female': 622,
#  'sign': 623,
#  'announces': 624,
#  'massive': 625,
#  'michelle': 626,
#  'hits': 627,
#  'kurdish': 628,
#  'benghazi': 629,
#  'transgender': 630,
#  'wife': 631,
#  'drops': 632,
#  'angry': 633,
#  'gay': 634,
#  'where': 635,
#  'march': 636,
#  'these': 637,
#  'tweets': 638,
#  'vows': 639,
#  'tell': 640,
#  'much': 641,
#  'global': 642,
#  'rejects': 643,
#  'warren': 644,
#  'middle': 645,
#  'rubio': 646,
#  'debt': 647,
#  'gave': 648,
#  'week': 649,
#  'macron': 650,
#  'videojuly': 651,
#  'youre': 652,
#  'kellyanne': 653,
#  'rips': 654,
#  'flynn': 655,
#  'four': 656,
#  'look': 657,
#  'doj': 658,
#  'start': 659,
#  'nyc': 660,
#  'hilariously': 661,
#  'sex': 662,
#  'seen': 663,
#  'proves': 664,
#  'finally': 665,
#  'epic': 666,
#  'fck': 667,
#  'questions': 668,
#  'rule': 669,
#  'pelosi': 670,
#  'oil': 671,
#  'dc': 672,
#  'let': 673,
#  'epa': 674,
#  'ny': 675,
#  'al': 676,
#  'united': 677,
#  'victims': 678,
#  'activist': 679,
#  'children': 680,
#  'thousands': 681,
#  'hopes': 682,
#  'king': 683,
#  'agree': 684,
#  'blames': 685,
#  'question': 686,
#  'aide': 687,
#  'office': 688,
#  'jr': 689,
#  'close': 690,
#  'released': 691,
#  'demands': 692,
#  'paris': 693,
#  'girl': 694,
#  'awesome': 695,
#  'barack': 696,
#  'second': 697,
#  'evidence': 698,
#  'through': 699,
#  'mike': 700,
#  'action': 701,
#  'russias': 702,
#  'ivanka': 703,
#  'act': 704,
#  'refuses': 705,
#  'thing': 706,
#  'pope': 707,
#  'charges': 708,
#  'cuba': 709,
#  'yet': 710,
#  'whoa': 711,
#  'london': 712,
#  'passes': 713,
#  'biden': 714,
#  'assault': 715,
#  'im': 716,
#  'videoaugust': 717,
#  'men': 718,
#  'running': 719,
#  'ceo': 720,
#  'conway': 721,
#  'videooctober': 722,
#  'disgusting': 723,
#  'brilliant': 724,
#  'service': 725,
#  'claim': 726,
#  'repeal': 727,
#  'part': 728,
#  'days': 729,
#  'chris': 730,
#  'least': 731,
#  'uses': 732,
#  'cuts': 733,
#  'protect': 734,
#  'arms': 735,
#  'committee': 736,
#  'fed': 737,
#  'liberals': 738,
#  'erdogan': 739,
#  'issues': 740,
#  'chinese': 741,
#  'corruption': 742,
#  'there': 743,
#  'ben': 744,
#  'shes': 745,
#  'approves': 746,
#  'battle': 747,
#  'kremlin': 748,
#  'water': 749,
#  'workers': 750,
#  'members': 751,
#  'talk': 752,
#  'melania': 753,
#  'xi': 754,
#  'hack': 755,
#  'street': 756,
#  'stand': 757,
#  'me': 758,
#  'crowd': 759,
#  'stunning': 760,
#  'crooked': 761,
#  'child': 762,
#  'inauguration': 763,
#  'civil': 764,
#  'block': 765,
#  'offers': 766,
#  'strikes': 767,
#  'forced': 768,
#  'owner': 769,
#  'faces': 770,
#  'getting': 771,
#  'comments': 772,
#  'releases': 773,
#  'private': 774,
#  'kelly': 775,
#  'town': 776,
#  'christian': 777,
#  'star': 778,
#  'theyre': 779,
#  'economic': 780,
#  'come': 781,
#  'nancy': 782,
#  'loses': 783,
#  'strike': 784,
#  'troops': 785,
#  'groups': 786,
#  'five': 787,
#  'ambassador': 788,
#  'philippines': 789,
#  'navy': 790,
#  'insane': 791,
#  'pressure': 792,
#  'join': 793,
#  'criminal': 794,
#  'puts': 795,
#  'alien': 796,
#  'perfect': 797,
#  'yr': 798,
#  'moore': 799,
#  'role': 800,
#  'student': 801,
#  'review': 802,
#  'name': 803,
#  'venezuela': 804,
#  'protests': 805,
#  'nato': 806,
#  'signs': 807,
#  'words': 808,
#  'break': 809,
#  'killing': 810,
#  'life': 811,
#  'immigrant': 812,
#  'millions': 813,
#  'intel': 814,
#  'soldiers': 815,
#  'accuses': 816,
#  'guy': 817,
#  'love': 818,
#  '911': 819,
#  'rant': 820,
#  'mcconnell': 821,
#  'abortion': 822,
#  'cabinet': 823,
#  'denies': 824,
#  'energy': 825,
#  'east': 826,
#  'return': 827,
#  'bank': 828,
#  'turn': 829,
#  'union': 830,
#  'statement': 831,
#  'hard': 832,
#  'something': 833,
#  'scandal': 834,
#  'crazy': 835,
#  'university': 836,
#  'wrong': 837,
#  'line': 838,
#  'cyber': 839,
#  'car': 840,
#  'little': 841,
#  'spicer': 842,
#  'night': 843,
#  'fans': 844,
#  'jail': 845,
#  'elizabeth': 846,
#  'speak': 847,
#  'letter': 848,
#  'human': 849,
#  'better': 850,
#  'dems': 851,
#  'citizens': 852,
#  'murder': 853,
#  'illegals': 854,
#  'envoy': 855,
#  'around': 856,
#  'test': 857,
#  'lose': 858,
#  'breaks': 859,
#  'dangerous': 860,
#  'suspected': 861,
#  'carson': 862,
#  'oops': 863,
#  'tucker': 864,
#  'warning': 865,
#  'staff': 866,
#  'confirms': 867,
#  'defend': 868,
#  'taking': 869,
#  'turkeys': 870,
#  'sunday': 871,
#  'care': 872,
#  'flashback': 873,
#  'trip': 874,
#  'michael': 875,
#  'agency': 876,
#  'michigan': 877,
#  'powerful': 878,
#  'arabia': 879,
#  'labor': 880,
#  'aliens': 881,
#  'deputy': 882,
#  'christmas': 883,
#  'leaves': 884,
#  'reports': 885,
#  'weapons': 886,
#  'terrorism': 887,
#  'vp': 888,
#  'americas': 889,
#  'mass': 890,
#  'stay': 891,
#  'embassy': 892,
#  'might': 893,
#  'target': 894,
#  'migrants': 895,
#  'destroyed': 896,
#  'soros': 897,
#  'james': 898,
#  'victory': 899,
#  'fund': 900,
#  'threats': 901,
#  'carolina': 902,
#  'history': 903,
#  'racism': 904,
#  'palin': 905,
#  'northern': 906,
#  'effort': 907,
#  'congressional': 908,
#  'israeli': 909,
#  'step': 910,
#  'mocks': 911,
#  'spending': 912,
#  'spy': 913,
#  'germanys': 914,
#  'sheriff': 915,
#  'anchor': 916,
#  'same': 917,
#  'catalonia': 918,
#  'urge': 919,
#  'transition': 920,
#  'stage': 921,
#  'find': 922,
#  'megyn': 923,
#  'worst': 924,
#  'explains': 925,
#  'accused': 926,
#  'charged': 927,
#  'lied': 928,
#  'koreas': 929,
#  'afghan': 930,
#  'furious': 931,
#  'view': 932,
#  'manager': 933,
#  'announcement': 934,
#  'picks': 935,
#  'things': 936,
#  'absolutely': 937,
#  'member': 938,
#  'many': 939,
#  'doing': 940,
#  'friend': 941,
#  'speaks': 942,
#  'ukraine': 943,
#  'answer': 944,
#  'tried': 945,
#  'drop': 946,
#  'hearing': 947,
#  'schools': 948,
#  'boy': 949,
#  'since': 950,
#  'front': 951,
#  'sht': 952,
#  'hannity': 953,
#  'actually': 954,
#  'mueller': 955,
#  'names': 956,
#  'red': 957,
#  'thinks': 958,
#  'bathroom': 959,
#  'drug': 960,
#  'frances': 961,
#  'food': 962,
#  'fighting': 963,
#  'mexican': 964,
#  'play': 965,
#  'church': 966,
#  'zimbabwe': 967,
#  'elections': 968,
#  'future': 969,
#  'fires': 970,
#  'sets': 971,
#  'candidates': 972,
#  'rich': 973,
#  'meets': 974,
#  'foundation': 975,
#  'videonovember': 976,
#  'virginia': 977,
#  'until': 978,
#  'financial': 979,
#  'far': 980,
#  'ask': 981,
#  'moscow': 982,
#  'then': 983,
#  'illinois': 984,
#  'teen': 985,
#  'heads': 986,
#  'number': 987,
#  'egypt': 988,
#  'exposed': 989,
#  'actor': 990,
#  'allow': 991,
#  'percent': 992,
#  'early': 993,
#  'pentagon': 994,
#  'confederate': 995,
#  'carlson': 996,
#  'challenge': 997,
#  'turns': 998,
#  'romney': 999,
#  'britains': 1000,
#  ...}

# %%
plt.hist([len(x) for x in X], bins = 700)
plt.show()

# %%
nos=np.array([len(x) for x in X])
len(nos[nos>1000])
# Out:
# 0

# %%
maxlen=1000
X=pad_sequences(X,maxlen=maxlen)

# %%
len(X[0])
# Out:
# 1000

# %%
vocab_size = len(tokenizer.word_index) + 1
vocab = tokenizer.word_index

# %%
def get_weight_matrix(model):
  weight_matrix = np.zeros((vocab_size, DIM))

  for word, i in vocab.items():
    weight_matrix[i]=model.wv[word]
  return weight_matrix

# %%
embedding_vectors = get_weight_matrix(w2v_model)

# %%
embedding_vectors.shape
# Out:
# (42958, 100)

# %%
model = Sequential()
model.add(Embedding(vocab_size, output_dim = DIM, weights = [embedding_vectors], input_length=maxlen, trainable= False))
model.add(LSTM(units=128))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1000, 100)         4295800
#
#  lstm (LSTM)                 (None, 128)               117248
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 4,413,177
# Trainable params: 117,377
# Non-trainable params: 4,295,800
# _________________________________________________________________

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
model.fit(X_train, y_train, validation_split=0.3, epochs=6)
# Out:
# Epoch 1/6
# 737/737 [==============================] - 57s 66ms/step - loss: 0.2506 - acc: 0.8937 - val_loss: 0.3336 - val_acc: 0.8610
# Epoch 2/6
# 737/737 [==============================] - 50s 68ms/step - loss: 0.1993 - acc: 0.9189 - val_loss: 0.1799 - val_acc: 0.9269
# Epoch 3/6
# 737/737 [==============================] - 46s 62ms/step - loss: 0.1724 - acc: 0.9313 - val_loss: 0.1801 - val_acc: 0.9269
# Epoch 4/6
# 737/737 [==============================] - 46s 63ms/step - loss: 0.1581 - acc: 0.9355 - val_loss: 0.1459 - val_acc: 0.9413
# Epoch 5/6
# 737/737 [==============================] - 46s 63ms/step - loss: 0.1477 - acc: 0.9412 - val_loss: 0.1496 - val_acc: 0.9381
# Epoch 6/6
# 737/737 [==============================] - 46s 63ms/step - loss: 0.1376 - acc: 0.9447 - val_loss: 0.1318 - val_acc: 0.9470

# %%
y_pred= (model.predict(X_test) >=0.5).astype(int)
# Out:
# 351/351 [==============================] - 9s 26ms/step

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9476169265033407

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      5874
#            1       0.94      0.95      0.95      5351
#
#     accuracy                           0.95     11225
#    macro avg       0.95      0.95      0.95     11225
# weighted avg       0.95      0.95      0.95     11225

# %%
X_test
# Out:
# array([[    0,     0,     0, ..., 11999,    33,     1],
#        [    0,     0,     0, ...,   195,    43,     1],
#        [    0,     0,     0, ..., 35965,    41,     1],
#        ...,
#        [    0,     0,     0, ...,  4551,    48,     1],
#        [    0,     0,     0, ..., 34725,    67,     1],
#        [    0,     0,     0, ..., 34636,    56,     1]], dtype=int32)

# %%
x=['Household incomes posted strong growth last year in more than a dozen U.S. congressional districts where Republicans face stiff challenges in November elections, according to a Reuters analysis of Census Bureau data published on Thursday.']
x=tokenizer.texts_to_sequences(x)
x=pad_sequences(x, maxlen=maxlen)

# %%
(model.predict(x) >= 0.5).astype(int)
# Out:
# 1/1 [==============================] - 0s 52ms/step
# array([[0]])

# %% [markdown]
# Save Model and use it

# %%
from tensorflow.keras.models import load_model
model.save('/content/drive/MyDrive/SavedModel/tmsSavedModelTitleDate.hdf5')

# %%
print(model)
# Out:
# <keras.engine.sequential.Sequential object at 0x7f141735a0a0>

# %% [markdown]
# After the model is saved

# %%
import tensorflow as tf
import gensim
from tensorflow.keras.preprocessing.text import Tokenizer #used to tokenize the text data
from tensorflow.keras.preprocessing.sequence import pad_sequences
maxlen=1000
tokenizer= Tokenizer()
'''tokenizer.fit_on_texts(X)
X = tokenizer.texts_to_sequences(X)'''
model_new = tf.keras.models.load_model("/content/drive/MyDrive/SavedModel/RNNSavedModelTitleDate.hdf5")

# %%
model_new.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1000, 100)         4295800
#
#  lstm (LSTM)                 (None, 128)               117248
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 4,413,177
# Trainable params: 117,377
# Non-trainable params: 4,295,800
# _________________________________________________________________

# %%
model_new.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
x=['Household incomes posted strong growth last year in more than a dozen U.S. congressional districts where Republicans face stiff challenges in November elections, according to a Reuters analysis of Census Bureau data published on Thursday.']
x=['Pakistan is beset by violence in July after the military storms an Islamabad mosque taken over by militant Islamists. On October 18, with pressure rising for new elections, former premier Benazir Bhutto returns from self-exile. A suicide bombing kills 139 people during her homecoming parade. On November 3, President Pervez Musharraf imposes a state of emergency, and then sets elections for January. The United States, which has built its "war on terror" on an alliance with Pakistan.']

tokenizer.fit_on_texts(x)
x=tokenizer.texts_to_sequences(x)
x=pad_sequences(x, maxlen=maxlen)
print(model_new.predict(x))
(model_new.predict(x)>=0.4).astype(int)
# Out:
# 1/1 [==============================] - 0s 356ms/step
# [[0.64203393]]
# 1/1 [==============================] - 0s 46ms/step
# array([[1]])
